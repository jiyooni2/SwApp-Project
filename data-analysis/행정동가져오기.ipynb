# %%
def open_api_reverse(x,y):
    import os
    import sys
    import urllib.request
    import json

    client_id="gryuyvyr2r"
    client_secret="QkkL7gWgeTAy8SeCwho8kz7HXsNw1tfahVchHod4"
    #client_id, client_secret 발급받아서 수정!!!!!
    x=urllib.parse.quote_plus(x)
    y=urllib.parse.quote_plus(y)
    url="https://naveropenapi.apigw.ntruss.com/map-reversegeocode/v2/gc?request=coordsToaddr&coords=%s,%s&sourcecrs=epsg:4326&output=json&orders=addr,admcode"%(x,y)


    request = urllib.request.Request(url)
    request.add_header("X-NCP-APIGW-API-KEY-ID", client_id)
    request.add_header("X-NCP-APIGW-API-KEY", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode == 200):
        response_body = response.read()
        data=json.loads(response_body)
        return data['results'][1]['region']['area3']['name']
    else:
        print("Error Code:" + rescode)
        print("Error address : ",address)

# %%
with open("C:\\Users\\kjy77\\1_Python\\LOCAL_PEOPLE\\coordlist.csv", 'r', encoding='utf-8-sig') as data_file:
    data_lines=csv.reader(data_file,delimiter=',')
    for idx,data_line in enumerate(data_lines):
        print(data_line)
# Out:
# ['개포동 개포우성3차', '127.0560485', '37.4839674']
# ['개포동 경남1', '127.0542279', '37.4848778']
# ['개포동 디에이치아너힐즈', '127.0672555', '37.4846559']
# ['개포동 래미안블레스티지', '127.064183', '37.481056']
# ['개포동 현대2', '127.0510516', '37.4827754']
# ['개포동 현대3', '127.0613774', '37.4877693']
# ['논현동 경남논현', '127.0381995', '37.5106658']
# ['논현동 논현동월드메르디앙', '127.033955', '37.5135683']
# ['논현동 논현베르빌', '127.0328', '37.5126583']
# ['논현동 논현웰스톤', '127.0380207', '37.5184409']
# ['논현동 논현파라곤', '127.0402809', '37.5165899']
# ['논현동 동부센트레빌', '127.0376964', '37.5103719']
# ['논현동 스위트캐슬레지던스', '127.0239816', '37.5124857']
# ['논현동 신동아(22)', '127.0228831', '37.5148589']
# ['논현동 아크로힐스논현', '127.0389463', '37.5095777']
# ['논현동 우성', '127.0280731', '37.5075536']
# ['논현동 은탑리더스카운티', '127.0239422', '37.5131641']
# ['논현동 테크노빌라트', '127.0402764', '37.5112431']
# ['논현동 한화꿈에그린2차', '127.030818', '37.5075691']
# ['대치동 개포우성1', '127.0597838', '37.4914207']
# ['대치동 대치우성아파트1동, 2동, 3동, 5동, 6동, 7동', '127.0705026', '37.5003949']
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\kjy77\\1_Python\\LOCAL_PEOPLE\\coordlist.csv", encoding='utf-8-sig',header=None)

# %%
dong=[]

# %%
new_dong=[]

for i in range(df.shape[0]):
    res=open_api_reverse(str(df.loc[i][1]),str(df.loc[i][2]))
    new_dong.append(res)

# %%
new_dong
# Out:
# ['개포1동',
#  '개포1동',
#  '개포2동',
#  '개포2동',
#  '개포4동',
#  '개포2동',
#  '논현2동',
#  '논현2동',
#  '논현2동',
#  '논현2동',
#  '논현2동',
#  '논현2동',
#  '논현1동',
#  '논현1동',
#  '논현2동',
#  '논현1동',
#  '논현1동',
#  '논현2동',
#  '논현1동',
#  '대치1동',
#  '대치2동',
#  '대치1동',
#  '대치1동',
#  '대치1동',
#  '대치2동',
#  '대치2동',
#  '대치2동',
#  '대치2동',
#  '도곡1동',
#  '도곡2동',
#  '도곡1동',
#  '도곡2동',
#  '도곡1동',
#  '도곡1동',
#  '도곡1동',
#  '도곡2동',
#  '도곡1동',
#  '도곡2동',
#  '도곡2동',
#  '도곡2동',
#  '도곡2동',
#  '도곡1동',
#  '도곡1동',
#  '삼성2동',
#  '삼성2동',
#  '삼성2동',
#  '삼성2동',
#  '삼성1동',
#  '삼성2동',
#  '삼성1동',
#  '수서동',
#  '압구정동',
#  '압구정동',
#  '신사동',
#  '신사동',
#  '신사동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '압구정동',
#  '역삼2동',
#  '역삼2동',
#  '역삼2동',
#  '역삼2동',
#  '역삼1동',
#  '역삼1동',
#  '역삼1동',
#  '역삼1동',
#  '역삼1동',
#  '역삼1동',
#  '역삼2동',
#  '역삼1동',
#  '일원2동',
#  '일원2동',
#  '일원본동',
#  '일원본동',
#  '세곡동',
#  '청담동',
#  '청담동',
#  '청담동',
#  '청담동',
#  '청담동',
#  '청담동',
#  '청담동',
#  '강일동',
#  '강일동',
# ...

# %%
df[3]=new_dong

# %%
df.columns=['아파트','x','y','행정동']
df
# Out:
#                           아파트           x          y   행정동
# 0                  개포동 개포우성3차  127.056049  37.483967  개포1동
# 1                     개포동 경남1  127.054228  37.484878  개포1동
# 2                개포동 디에이치아너힐즈  127.067256  37.484656  개포2동
# 3                개포동 래미안블레스티지  127.064183  37.481056  개포2동
# 4                     개포동 현대2  127.051052  37.482775  개포4동
# ...                       ...         ...        ...   ...
# 1183  진관동 은평뉴타운 폭포동(힐스테이트D-9)  126.931985  37.629772   진관동
# 1184                 창신동 창신이수  127.015047  37.577905  창신3동
# 1185                 평창동 밀레니엄  126.967544  37.606858   평창동
# 1186             묵동 묵동자이(2단지)  127.077697  37.613882   묵1동
# 1187                신내동 다우훼밀리  127.096057  37.600461  신내1동
#
# [1188 rows x 4 columns]

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

engine = create_engine("mysql+mysqldb://root:"+"sql2017920017"+"@localhost/school", encoding='utf-8')
conn = engine.connect()

df.to_sql(name="dong",con=engine,if_exists='append',index=False)
conn.close()
